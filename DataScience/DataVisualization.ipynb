# %%
import pandas as pd # tabelas 

# graficos 
import seaborn as sns 
import matplotlib.pyplot as plt
import plotly.express as px
# graficos

# %%
penguins = sns.load_dataset("penguins")
penguins.shape
# Out:
# (344, 7)

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
# Exclui todos os dados em branco (Nan)
penguins.dropna()
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.groupby(['species']).size()
# Out:
# species
# Adelie       152
# Chinstrap     68
# Gentoo       124
# dtype: int64

# %%
penguins.groupby(['sex']).size()
# Out:
# sex
# Female    165
# Male      168
# dtype: int64

# %%
penguins.groupby(['island']).size()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# dtype: int64

# %% [markdown]
# # body_mass_g

# %%
sns.set_theme(style='darkgrid')
sns.displot(
    penguins, x='body_mass_g', row='sex'
)

# %%
sns.displot(
    penguins, x='body_mass_g', col='species'
)

# %%
sns.displot(
    penguins, x='body_mass_g', col='species', row='sex'
)

# %% [markdown]
# # Island

# %%
sns.displot(
    penguins, x='island'
)

# %%
sns.displot(
    penguins, x='island', col='sex'
)

# %%
sns.displot(
    penguins, x='island', col='species'
)

# %%
fig = px.histogram(
  penguins, x='island', color='sex'
)
fig.show()

# %%
fig = px.pie(
    penguins, 
    
    names='sex'
)
fig.show()

# %% [markdown]
# # Titanic

# %%
# Carrega os dados
titanic = sns.load_dataset("titanic")

# Mostra os dados
titanic.head(2)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %%
titanic.loc[titanic['survived'] == 0, 'survived'] = 'no'
titanic.loc[titanic['survived'] == 1, 'survived'] = 'yes'
titanic.head(2)
# Out:
#   survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0       no       3    male  22.0      1      0   7.2500        S  Third
# 1      yes       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %%
counts_survived = titanic['survived'].value_counts()
counts_survived
# Out:
# no     549
# yes    342
# Name: survived, dtype: int64

# %%
# Plotly = px

px.pie(titanic, names=counts_survived.index, values=counts_survived.values, hole=.5, width=600, height=300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 # Plotly = px
# ----> 3 px.pie(titanic, names=counts_survived.index, values=counts_survived.values, hole=.5, width=600, height=300)
#
# NameError: name 'counts_survived' is not defined

# %%
px.bar(titanic, x='sex', y='survived', width=800, height=400)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(titanic,x='sex', y=counts_survived, width=800, height=400)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-511f96cc7f40> in <cell line: 1>()
# ----> 1 px.scatter(titanic,x='sex', y=counts_survived, width=800, height=400)
#
# /usr/local/lib/python3.9/dist-packages/plotly/express/_chart_types.py in scatter(data_frame, x, y, color, symbol, size, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, marginal_x, marginal_y, trendline, trendline_options, trendline_color_override, trendline_scope, log_x, log_y, range_x, range_y, render_mode, title, template, width, height)
# ...
