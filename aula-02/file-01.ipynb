# %%
# import food
# import drink

# drink.coca()
# food.pizza()

# from food import pizza, salad
# from drink import coca, coffee

# coca()
# pizza()
# salad()

# %%
import math
# from math import pow, ceil
# sqrt, floor, ceil, pow

# %%
n1 = int(input('Entre com um numero: '))
# Out:
# Entre com um numero: 31

# %%
9 ** 2
# Out:
# 81

# %%
# math.pow(9,2)
# Out:
# 81

# %%
raiz = math.sqrt(n1)

print(f'Raiz quadrada de {n1} é {raiz:.3}')

print(math.ceil(raiz))
# Out:
# Raiz quadrada de 31 é 5.57
# 6

# %%
from random import randint, randrange

# %%
n1 = randint(1, 10)
n2 = randint(11, 20)

# %%
print(f'{n1} + {n2} = {n1 + n2}')
# Out:
# 3 + 14 = 17

# %%
print(f'{n1}^{n2} = {math.pow(n1, n2)}')
# Out:
# 3^14 = 4782969.0

# %%
print(f'{n1} sqrt {n2} = {math.sqrt(n1 + n2)}')
# Out:
# 3 sqrt 14 = 4.123105625617661

# %%
import datetime as dt

# %%
dt.datetime.now()
# Out:
# datetime.datetime(2023, 1, 18, 12, 58, 12, 245816)

# %%
import pandas as pd
