# %% [markdown]
# LISTA []
#
# https://www.w3schools.com/python/python_lists.asp

# %%
numList = [5,3,9,0,2]
stgList = ['Gabriel', 'Renzo', 'Andre', 'Laisa']
booList = [True, False]
myList = [1, 'Gabriel', False]

# %%
print(stgList[0])
print(stgList[1])
print(stgList[2])
print(stgList[3])
# Out:
# Gabriel
# Renzo
# Andre
# Laisa

# %%
pos = 0 
lenList = len(stgList)

while pos < lenList:
  print(pos, stgList[pos])
  pos += 1
# Out:
# 0 Gabriel
# 1 Renzo
# 2 Andre
# 3 Laisa

# %%
for i in range(4):
  print(i, stgList[i])
# Out:
# 0 Gabriel
# 1 Renzo
# 2 Andre
# 3 Laisa

# %%
for i in stgList:
  print(i)
# Out:
# Gabriel
# Renzo
# Andre
# Laisa

# %%
# Conta o numero de itens em uma lista
lenList = len(numList)
lenList
# Out:
# 5

# %%
# 
numList.sort()
print(numList)
# Out:
# [0, 2, 3, 5, 9]

# %%
numList.pop(2)
numList
# Out:
# [0, 2, 5, 9]

# %%
# Adicionando um elemento no final da lista
numList.append(3)
numList
# Out:
# [0, 2, 5, 9, 3]

# %%
numList.sort()
print(numList)
# Out:
# [0, 2, 3, 5, 9]

# %%
lanche = ['suco', 'sanduish', 'picole', 'pudim', 'pizza']

# %%
# Adicionando elemento em qualquer posição
lanche.insert(3, 'hamburger')
lanche
# Out:
# ['hamburger', 'suco', 'sanduish', 'hamburger', 'picole', 'pudim', 'pizza']

# %%
# Removendo elemento 
lanche.remove('pizza')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-9aefd4be677a> in <module>
#       1 # Removendo elemento
# ----> 2 lanche.remove('pizza')
#
# ValueError: list.remove(x): x not in list

# %%
# Checa se existe o elemento dentro da lista
if 'pizza' in lanche:
  lanche.remove('pizza')
else:
  print('elemento não existe na lista')

lanche
# Out:
# elemento não existe na lista
# ['suco', 'sanduish', 'hamburger', 'picole', 'pudim']

# %%
# Lista dentro de lista
pessoa = ['Pedro', 20]
pessoa = ['Luisa', 30]

pessoas = [['Pedro', 20], ['Luisa', 30]]

# %%
pessoas[0]
# Out:
# ['Pedro', 20]

# %%
pessoas[1][0]
# Out:
# 'Luisa'

# %%
valores = list()
valores
# Out:
# []

# %%
num = int(input('Numero: '))
num
# Out:
# Numero: 3
# 3

# %%
valores.append(num)
valores
# Out:
# [3]

# %%
for i in range(3):
  valores.append(int(input('Numero: ')))

print(valores)

print(len(valores))

valores.sort()

print(valores)
# Out:
# Numero: 12
# Numero: 8
# Numero: 1
# [3, 5, 6, 9, 2, 0, 7, 12, 8, 1]
# 10
