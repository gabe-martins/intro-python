# %% [markdown]
# TUPLAS ()
#
# https://www.w3schools.com/python/python_tuples.asp

# %%
# Variaveis simples 
nome = 'Renzo'
nome
# Out:
# 'Renzo'

# %%
# Variaveis compostas
# São imutaveis = não mudam

lanche = ('Hamburger', 'Suco', 'Pudim', 'Pizza')
lanche
# Out:
# ('Hamburger', 'Suco', 'Pudim', 'Pizza')

# %%
len(lanche)
# Out:
# 4

# %%
lanche[1:]
# Out:
# ('Suco', 'Pudim', 'Pizza')

# %%
lanche[1:3]
# Out:
# ('Suco', 'Pudim')

# %%
lanche[2:]
# Out:
# ('Pudim', 'Pizza')

# %%
# Ordenar tupla
sorted(lanche)
# Out:
# ['Hamburger', 'Pizza', 'Pudim', 'Suco']

# %%
numeros = (4,7,2,5,8)

sorted(numeros)
# Out:
# [2, 4, 5, 7, 8]

# %%
for c in lanche:
  print(f'Hoje meu lanche é {c}')
# Out:
# Hoje meu lanche é Hamburger
# Hoje meu lanche é Suco
# Hoje meu lanche é Pudim
# Hoje meu lanche é Pizza

# %%
for c in lanche[1:3]:
  print(c)
# Out:
# Suco
# Pudim

# %%
lanche[0:2]
# Out:
# ('Hamburger', 'Suco')

# %%
lanche[1]
# Out:
# 'Suco'

# %%
cont = ('zero', 'um', 'dois', 'tres', 'quatro')

while True:

  num = int(input('Digite um numero entre 0 e 20'))

  if 0 <= num <= 20:
    break

  print('Tente novamente.', end='')

print(f'você digitou {cont[num]}')

# %%
num = int(input('Escolha seu lanche entre 0 e 3: '))

print(f'Seu lanche é: {lanche[num]}')
# Out:
# Escolha seu lanche entre 0 e 3: 1
# Seu lanche é: Suco
